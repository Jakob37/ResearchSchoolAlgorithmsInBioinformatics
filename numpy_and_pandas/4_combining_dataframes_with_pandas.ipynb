# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Concatenating-DataFrames" data-toc-modified-id="Concatenating-DataFrames-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Concatenating DataFrames</a></div><div class="lev1 toc-item"><a href="#Joining-dataframes" data-toc-modified-id="Joining-dataframes-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Joining dataframes</a></div>

# %%
import pandas as pd

# %%
surveys_df = pd.read_csv("../data/ecol_data_part1.csv", keep_default_na=False, na_values=[""])

# %%
surveys_df.head()
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
#
#    weight
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %% [markdown]
# # Concatenating DataFrames

# %%
survey_sub = surveys_df.head(10)
survey_sub_last10 = surveys_df.tail(10)
# Aha, so row IDs go from 0 again
survey_sub_last10 = survey_sub_last10.reset_index(drop=True)

survey_sub_last10.head(10)
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# 2      35542     12   31  2002       15         PB    F             26.0
# 3      35543     12   31  2002       15         PB    F             27.0
# 4      35544     12   31  2002       15         US  NaN              NaN
# 5      35545     12   31  2002       15         AH  NaN              NaN
# 6      35546     12   31  2002       15         AH  NaN              NaN
# 7      35547     12   31  2002       10         RM    F             15.0
# 8      35548     12   31  2002        7         DO    M             36.0
# 9      35549     12   31  2002        5        NaN  NaN              NaN
#
#    weight
# 0    23.0
# 1    31.0
# 2    29.0
# 3    34.0
# 4     NaN
# 5     NaN
# 6     NaN
# 7    14.0
# 8    51.0
# 9     NaN

# %%
vertical_stack = pd.concat([survey_sub, survey_sub_last10], axis=0)
vertical_stack
# Out:
#    record_id  month  day  year  plot_id species_id  sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL    M             32.0
# 1          2      7   16  1977        3         NL    M             33.0
# 2          3      7   16  1977        2         DM    F             37.0
# 3          4      7   16  1977        7         DM    M             36.0
# 4          5      7   16  1977        3         DM    M             35.0
# 5          6      7   16  1977        1         PF    M             14.0
# 6          7      7   16  1977        2         PE    F              NaN
# 7          8      7   16  1977        1         DM    M             37.0
# 8          9      7   16  1977        1         DM    F             34.0
# 9         10      7   16  1977        6         PF    F             20.0
# 0      35540     12   31  2002       15         PB    F             26.0
# 1      35541     12   31  2002       15         PB    F             24.0
# ...

# %%
horizontal_stack = pd.concat([survey_sub, survey_sub_last10], axis=1)
horizontal_stack
# Out:
#    record_id  month  day  year  plot_id species_id sex  hindfoot_length  \
# 0          1      7   16  1977        2         NL   M             32.0
# 1          2      7   16  1977        3         NL   M             33.0
# 2          3      7   16  1977        2         DM   F             37.0
# 3          4      7   16  1977        7         DM   M             36.0
# 4          5      7   16  1977        3         DM   M             35.0
# 5          6      7   16  1977        1         PF   M             14.0
# 6          7      7   16  1977        2         PE   F              NaN
# 7          8      7   16  1977        1         DM   M             37.0
# 8          9      7   16  1977        1         DM   F             34.0
# 9         10      7   16  1977        6         PF   F             20.0
#
#    weight  record_id  month  day  year  plot_id species_id  sex  \
# 0     NaN      35540     12   31  2002       15         PB    F
# ...

# %% [markdown]
# # Joining dataframes
#
# Previously, we just stacked dataframes vertically or horizontally. Now, let's join on index.
#
# * Identify keys for fields shared between the files
#
# We can then do an *inner join*, meaning returning only rows with matching values in both original DataFrames.

# %%
survey_sub = surveys_df.head(10)

# %%
# merged_inner = pd.merge(left=survey_sub, right=species_sub, left_on='species_id', right_on='species_id')

# %% [markdown]
# We can do left joins, where we add information from second table without losing anything from the first one. This is also called *left outer join*.
